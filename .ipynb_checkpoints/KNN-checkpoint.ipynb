# %%
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %%
'pH'
#This is for pH model
datapH = pd.read_excel('paper_polymer_data.xlsx', sheet_name=0)
print(datapH.head())

varpH = ['pH','PAM','HMTA','HQ','T']
X = datapH[varpH]
y = datapH['lnt, lab']
X2 = X[:78]
y2 = y[:78]
# Out:
#    Unnamed: 0   pH  PAM  HMTA   HQ    T  PAM.1  HMTA.1  HQ.1   T [K]  t, lab  \
# 0           0  8.0  1.0   0.3  0.2   85    1.0     0.3   0.2  358.15   140.0
# 1           1  8.0  1.0   0.3  0.2  100    1.0     0.3   0.2  373.15    72.0
# 2           2  8.0  1.0   0.3  0.2  110    1.0     0.3   0.2  383.15    15.0
# 3           3  8.0  1.0   0.3  0.2  120    1.0     0.3   0.2  393.15    10.0
# 4           4  8.5  1.0   0.3  0.2   85    1.0     0.3   0.2  358.15   150.0
#
#    lnt, lab       lnt  lnt no 7/8      MPL1      MPL2      CNN1      CNN2
# 0  4.941642  5.125799    5.250283  5.296560  5.208713  5.033586  5.063197
# 1  4.276666  3.841086    3.851911  4.081019  3.858882  3.841978  3.635168
# 2  2.708050  3.040495    2.980491  3.270659  2.958995  3.004539  2.723117
# 3  2.302585  2.280631    2.153402  2.460298  2.059107  2.167107  1.929965
# 4  5.010635  5.226536    5.205831  5.415755  5.173816  5.101276  4.923721

# %%
train_X, test_X, train_y, test_y = train_test_split(X2, y2, random_state =0)

# %%
'
knn = KNeighborsRegressor()
knn.fit(train_X, train_y)
# Out:
# KNeighborsRegressor()

# %%
pred_y = knn.predict(test_X)
knn_mae = mean_absolute_error(test_y,pred_y)
mean_y = np.mean(y)
print(knn_mae)
# Out:
# 0.3712183039978341

# %%
test_yy = np.array(test_y)
print(knn.score(test_X, test_y), 'R-squared score')
# Out:
# 0.805762015628767 R-squared score

# %%
fig, ax = plt.subplots()
ax.scatter(test_y, pred_y, color = 'red')
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'b--', lw=1)
ax.set_title('Gelation Time as Concentration and Temperature Function')
ax.set_xlabel('Measured [hours]')
ax.set_ylabel('Predicted [hours]')
plt.show()

# %%
predKNN = knn.predict(X)

df = pd.DataFrame(predKNN)
df.to_csv('predKNN.csv', index=False)

# %%
'SALINITY'
# Out:
# 'SALINITY'

# %%
datapH = pd.read_excel('paper_polymer_data.xlsx', sheet_name=1)
print(datapH.head())

varSal= ['Salinity','T (K)']
X = datapH[varSal]
y = datapH['ln t']
print(y)
# Out:
#    Unnamed: 0      ln t   t (hours)  T (K)  Salinity    ln t.1
# 0           0  4.785086  119.711603    358       1.0  4.785086
# 1           1  4.868655  130.145782    358       1.5  4.868655
# 2           2  4.968939  143.874131    358       2.0  4.968939
# 3           3  5.102650  164.457193    358       2.5  5.102650
# 4           4  5.186220  178.791439    358       3.0  5.186220
# 0     4.785086
# 1     4.868655
# 2     4.968939
# 3     5.102650
# 4     5.186220
# 5     4.283667
# 6     4.383951
# 7     4.500949
# 8     4.601232
# 9     4.684802
# 10    2.695844
# 11    2.879697
# 12    3.197262
# 13    3.548254
# 14    3.899247
# 15    2.294709
# 16    2.461849
# 17    2.762699
# 18    2.979981
# 19    3.213976
# Name: ln t, dtype: float64

# %%
# print(X, y)
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state =0)

# %%
knn = KNeighborsRegressor()
knn.fit(train_X, train_y)
# Out:
# KNeighborsRegressor()

# %%
pred_y = knn.predict(test_X)
knn_mae = mean_absolute_error(test_y,pred_y)
mean_y = np.mean(y)
print(knn_mae)
# Out:
# 0.28747968045623445

# %%
test_yy = np.array(test_y)
# print(test_yy)
# print(pred_y)
print(knn.score(test_X, test_y), 'R-squared score')
# Out:
# 0.7709703970709275 R-squared score

# %%
fig, ax = plt.subplots()
ax.scatter(test_y, pred_y, color = 'red')
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'b--', lw=1)
ax.set_title('Gelation Time as Salinity and Temperature Function')
ax.set_xlabel('Measured [hours]')
ax.set_ylabel('Predicted [hours]')
plt.show()

# %%
yy_pred = knn.predict(X)
print(yy_pred)
print(y)
# Out:
# [4.86531243 4.88536915 4.90876866 4.94553932 4.94553932 4.14661323
#  4.14661323 4.21012618 4.28032471 4.35052324 3.56162551 3.19726173
#  3.25743189 3.25743189 3.6418524  2.71924319 2.71924319 2.71924319
#  2.99335172 2.99335172]
# 0     4.785086
# 1     4.868655
# 2     4.968939
# 3     5.102650
# 4     5.186220
# 5     4.283667
# 6     4.383951
# 7     4.500949
# 8     4.601232
# 9     4.684802
# 10    2.695844
# 11    2.879697
# 12    3.197262
# 13    3.548254
# 14    3.899247
# 15    2.294709
# 16    2.461849
# 17    2.762699
# 18    2.979981
# 19    3.213976
# Name: ln t, dtype: float64

# %%
df = pd.DataFrame(yy_pred)
df.to_csv('predKNN_Sal.csv', index=False)

# %%
x = X.values
y = np.array(y).astype(int)
k = 10

clf = neighbors.KNeighborsClassifier(n_neighbors=k)
clf.fit(x, y)
# Plotting decision region
plot_decision_regions(x, y, clf=clf, legend=2)
# Adding axes annotations
# plt.xlabel(‘X’)
# plt.ylabel(‘Y’)
# plt.title(‘Knn with K=’+ str(k))
plt.show()
# Out:
# C:\Users\Arifurrahman\anaconda3\lib\site-packages\mlxtend\plotting\decision_regions.py:306: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   **scatter_kwargs

# %%
x = data[[‘X’,’Y’]].values
y = data[‘class’].astype(int).values
clf = neighbors.KNeighborsClassifier(n_neighbors=k)
clf.fit(x, y)
# Plotting decision region
plot_decision_regions(x, y, clf=clf, legend=2)
# Adding axes annotations
plt.xlabel(‘X’)
plt.ylabel(‘Y’)
plt.title(‘Knn with K=’+ str(k))
plt.show()

# %%
def knn_comparison(data, k):
    x = X
    y = y
    clf = neighbors.KNeighborsClassifier(n_neighbors=k)
    clf.fit(x, y)
    # Plotting decision region
    plot_decision_regions(x, y, clf=clf, legend=2)
    # Adding axes annotations
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Knn with K='+ str(k))
    plt.show()

# %%
import mglearn
print("mglearn version: {}".format(mglearn.__version__))

mglearn.plots.plot_knn_regression(n_neighbors=5)
# Out:
# mglearn version: 0.1.9

# %%
line = np.linspace(-3, 3, 1000).reshape(-1, 1)
print(line)
# Out:
# [[-3.        ]
#  [-2.99399399]
#  [-2.98798799]
#  [-2.98198198]
#  [-2.97597598]
#  [-2.96996997]
#  [-2.96396396]
#  [-2.95795796]
#  [-2.95195195]
#  [-2.94594595]
#  [-2.93993994]
#  [-2.93393393]
#  [-2.92792793]
#  [-2.92192192]
#  [ 1.25825826]
#  [ 1.26426426]
#  [ 1.27027027]
#  [ 1.27627628]
#  [ 1.28228228]
#  [ 1.28828829]
#  [ 1.29429429]
#  [ 1.3003003 ]
#  [ 1.30630631]
#  [ 1.31231231]
#  [ 1.31831832]
#  [ 1.32432432]
#  [ 1.33033033]
#  [ 1.33633634]
#  [ 1.34234234]
#  [ 1.34834835]
#  [ 1.35435435]
#  [ 1.36036036]
#  [ 1.36636637]
#  [ 1.37237237]
#  [ 1.37837838]
#  [ 1.38438438]
#  [ 1.39039039]
#  [ 1.3963964 ]
#  [ 1.4024024 ]
#  [ 1.40840841]
#  [ 1.41441441]
#  [ 1.42042042]
#  [ 1.42642643]
#  [ 1.43243243]
#  [ 1.43843844]
#  [ 1.44444444]
#  [ 1.45045045]
#  [ 1.45645646]
#  [ 1.46246246]
#  [ 1.46846847]
#  [ 1.47447447]
#  [ 1.48048048]
#  [ 1.48648649]
#  [ 1.49249249]
#  [ 1.4984985 ]
#  [ 1.5045045 ]
#  [ 1.51051051]
#  [ 1.51651652]
#  [ 1.52252252]
#  [ 1.52852853]
#  [ 1.53453453]
#  [ 1.54054054]
#  [ 1.54654655]
#  [ 1.55255255]
#  [ 1.55855856]
#  [ 1.56456456]
#  [ 1.57057057]
#  [ 1.57657658]
#  [ 1.58258258]
#  [ 1.58858859]
#  [ 1.59459459]
#  [ 1.6006006 ]
#  [ 1.60660661]
#  [ 1.61261261]
#  [ 1.61861862]
#  [ 1.62462462]
#  [ 1.63063063]
#  [ 1.63663664]
#  [ 1.64264264]
#  [ 1.64864865]
#  [ 1.65465465]
#  [ 1.66066066]
#  [ 1.66666667]
#  [ 1.67267267]
#  [ 1.67867868]
#  [ 1.68468468]
#  [ 1.69069069]
#  [ 1.6966967 ]
#  [ 1.7027027 ]
#  [ 1.70870871]
#  [ 1.71471471]
#  [ 1.72072072]
#  [ 1.72672673]
#  [ 1.73273273]
#  [ 1.73873874]
#  [ 1.74474474]
#  [ 1.75075075]
#  [ 1.75675676]
#  [ 1.76276276]
#  [ 1.76876877]
#  [ 1.77477477]
#  [ 1.78078078]
#  [ 1.78678679]
#  [ 1.79279279]
#  [ 1.7987988 ]
#  [ 1.8048048 ]
#  [ 1.81081081]
#  [ 1.81681682]
#  [ 1.82282282]
#  [ 1.82882883]
#  [ 1.83483483]
#  [ 1.84084084]
#  [ 1.84684685]
#  [ 1.85285285]
#  [ 1.85885886]
#  [ 1.86486486]
#  [ 1.87087087]
#  [ 1.87687688]
#  [ 1.88288288]
#  [ 1.88888889]
#  [ 1.89489489]
#  [ 1.9009009 ]
#  [ 1.90690691]
#  [ 1.91291291]
#  [ 1.91891892]
#  [ 1.92492492]
#  [ 1.93093093]
#  [ 1.93693694]
#  [ 1.94294294]
#  [ 1.94894895]
#  [ 1.95495495]
#  [ 1.96096096]
#  [ 1.96696697]
#  [ 1.97297297]
#  [ 1.97897898]
#  [ 1.98498498]
#  [ 1.99099099]
#  [ 1.996997  ]
#  [ 2.003003  ]
#  [ 2.00900901]
#  [ 2.01501502]
#  [ 2.02102102]
#  [ 2.02702703]
#  [ 2.03303303]
#  [ 2.03903904]
#  [ 2.83183183]
#  [ 2.83783784]
#  [ 2.84384384]
#  [ 2.84984985]
#  [ 2.85585586]
#  [ 2.86186186]
#  [ 2.86786787]
#  [ 2.87387387]
#  [ 2.87987988]
#  [ 2.88588589]
#  [ 2.89189189]
#  [ 2.8978979 ]
#  [ 2.9039039 ]
#  [ 2.90990991]
#  [ 2.91591592]
#  [ 2.92192192]
#  [ 2.92792793]
#  [ 2.93393393]
#  [ 2.93993994]
#  [ 2.94594595]
#  [ 2.95195195]
#  [ 2.95795796]
#  [ 2.96396396]
#  [ 2.96996997]
#  [ 2.97597598]
#  [ 2.98198198]
#  [ 2.98798799]
#  [ 2.99399399]
#  [ 3.        ]]

# %%
XX = np.array(train_X.iloc[:,0])
YY = np.array(train_y)
print(YY)
# Out:
# [2.76269942 4.38395111 3.54825436 5.18621998 4.96893883 4.2836675
#  3.899247   4.68480194 4.50094865 2.46184859 2.87969697 5.10265031
#  4.78508555 2.29470924 3.19726173]

# %%
# line = np.linspace(-3, 3, 1000).reshape(-1, 1)
# for n_neighbors, ax in zip([1, 3, 9], axes):
#     # make predictions using 1, 3, or 9 neighbors
#     reg = KNeighborsRegressor(n_neighbors=n_neighbors)
#     reg.fit(X_train, y_train)
#     ax.plot(line, reg.predict(line))
# fig, axes = plt.subplots(1, figsize=(15, 4))

# ax.plot(train_X.iloc[:,0], train_y, "^", c=mglearn.cm2(0), markersize=8),
ax.plot(XX, YY, 'v', c=mglearn.cm2(1), markersize=8)
fig
#     ax.set_title(
#         "{} neighbor(s)\n train score: {:.2f} test score: {:.2f}".format(
#             n_neighbors, reg.score(X_train, y_train),
#             reg.score(X_test, y_test)))
#     ax.set_xlabel("Feature")
#     ax.set_ylabel("Target")
# axes[0].legend(["Model predictions", "Training data/target",
#             "Test data/target"], loc="best")

# %%
line = np.linspace(1, 3, 9).reshape(-1, 1)
line2 = np.linspace(353, 393,9).reshape(-1,1)
line3 = np.column_stack([line, line2])
print(line3.shape)
# Out:
# (9, 2)

# %%
train_X
# Out:
#     Salinity  T (K)
# 17       2.0    393
# 6        1.5    373
# 13       2.5    383
# 4        3.0    358
# 2        2.0    358
# 5        1.0    373
# 14       3.0    383
# 9        3.0    373
# 7        2.0    373
# 16       1.5    393
# 11       1.5    383
# 3        2.5    358
# 0        1.0    358
# 15       1.0    393
# 12       2.0    383

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Create 1,000 data points, evenly spaced between -3 and 3

for n_neighbors, ax in zip([5], axes):
    # make predictions using 1, 3, or 9 neighbors
    reg = KNeighborsRegressor(n_neighbors=n_neighbors)
    reg.fit(train_X, train_y)
    ax.plot(line, reg.predict(line3))
    ax.plot(train_X.iloc[:,0], train_y, "^", c=mglearn.cm2(0), markersize=8)
    ax.plot(test_X.iloc[:,0], test_y, 'v', c=mglearn.cm2(1), markersize=8)
    ax.set_title(
        "{} neighbor(s)\n train score: {:.2f} test score: {:.2f}".format(
            n_neighbors, reg.score(train_X, train_y),
            reg.score(test_X, test_y)))
    ax.set_xlabel("Feature")
    ax.set_ylabel("Target")
axes[0].legend(["Model predictions", "Training data/target",
            "Test data/target"], loc="best")
# Out:
# C:\Users\Arifurrahman\anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   "X does not have valid feature names, but"
